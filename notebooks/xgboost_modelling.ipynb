# %%
import rdkit
import pandas as pd
from rdkit import Chem
import numpy as np
from tune_sklearn import TuneSearchCV
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect
from rdkit.DataStructs.cDataStructs import ConvertToNumpyArray
import molvs
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from rdkit.Chem.SaltRemover import SaltRemover

def ecfp( mol, r=3, nBits=2048, errors_as_zeros=True):
    mol = Chem.MolFromSmiles(mol) if not isinstance(mol, rdkit.Chem.rdchem.Mol) else mol
    try:
        arr = np.zeros((1,))
        ConvertToNumpyArray(GetMorganFingerprintAsBitVect(mol, r, nBits), arr)
        return arr.astype(np.float32)
    except:
        return np.NaN if not errors_as_zeros else np.zeros((nBits,), dtype=np.float32)

# %%
ames = pd.read_csv("../data/Mutagenicity_N6512.csv")[['Canonical_Smiles','Activity']].rename(columns={'Canonical_Smiles':'smiles',"Activity":"y"})
er = pd.read_csv("../data/ER.csv")[['Smiles','Class']].rename(columns={'Smiles':'smiles',"Class":"y"})
s = molvs.Standardizer()
salts = SaltRemover()

def process(smiles): #Some of molecules are broken (2 instead of 1) we will remove this data
   try:
       m =  Chem.MolFromSmiles(smiles)
       m = s.standardize(m)
       m = salts(m)
       arr = np.zeros((1,))
       ConvertToNumpyArray(GetMorganFingerprintAsBitVect(m, 3, 2048), arr)
       return arr.astype(np.float32)
   except:
       return None

# %%
er['X'] = er['smiles'].apply(process)
ames['X'] = ames['smiles'].apply(process)
er.dropna(inplace=True)
ames.dropna(inplace=True)
# Out:
# [16:59:40] SMILES Parse Error: syntax error while parsing: CCC1(c2ccccc2)C(=O)NC(=O)NC1=O,
# [16:59:40] SMILES Parse Error: Failed parsing SMILES 'CCC1(c2ccccc2)C(=O)NC(=O)NC1=O,' for input: 'CCC1(c2ccccc2)C(=O)NC(=O)NC1=O,'
# [16:59:40] SMILES Parse Error: syntax error while parsing: CCC1(CC)C(=O)NC(=O)NC1=O,
# [16:59:40] SMILES Parse Error: Failed parsing SMILES 'CCC1(CC)C(=O)NC(=O)NC1=O,' for input: 'CCC1(CC)C(=O)NC(=O)NC1=O,'
# [16:59:42] SMILES Parse Error: syntax error while parsing: Oc1cc2OC(=O)c3c(oc4cc(O)ccc43)-c2cc1,
# [16:59:42] SMILES Parse Error: Failed parsing SMILES 'Oc1cc2OC(=O)c3c(oc4cc(O)ccc43)-c2cc1,' for input: 'Oc1cc2OC(=O)c3c(oc4cc(O)ccc43)-c2cc1,'
# [16:59:44] SMILES Parse Error: syntax error while parsing: O=C1N(Cl)C(=O)NC(=O)N1Cl,
# [16:59:44] SMILES Parse Error: Failed parsing SMILES 'O=C1N(Cl)C(=O)NC(=O)N1Cl,' for input: 'O=C1N(Cl)C(=O)NC(=O)N1Cl,'
# [16:59:46] SMILES Parse Error: syntax error while parsing: CC1=NN=C(C(=O)N1N)c1ccccc1,
# [16:59:46] SMILES Parse Error: Failed parsing SMILES 'CC1=NN=C(C(=O)N1N)c1ccccc1,' for input: 'CC1=NN=C(C(=O)N1N)c1ccccc1,'
# [16:59:46] SMILES Parse Error: syntax error while parsing: CCSC1=NN=C(C(=O)N1N)C(C)(C)C,
# [16:59:46] SMILES Parse Error: Failed parsing SMILES 'CCSC1=NN=C(C(=O)N1N)C(C)(C)C,' for input: 'CCSC1=NN=C(C(=O)N1N)C(C)(C)C,'
# [16:59:47] SMILES Parse Error: syntax error while parsing: COc1c(CS(=O)c2[nH]c3ccc(cc3[n]2)OC(F)F)[n]ccc1OC,
# [16:59:47] SMILES Parse Error: Failed parsing SMILES 'COc1c(CS(=O)c2[nH]c3ccc(cc3[n]2)OC(F)F)[n]ccc1OC,' for input: 'COc1c(CS(=O)c2[nH]c3ccc(cc3[n]2)OC(F)F)[n]ccc1OC,'
# [16:59:47] SMILES Parse Error: syntax error while parsing: CC12CCC3C(C1CCC2O)C(Cc1cc(O)ccc13)CCCCCCCCCS(=O)CCCC(F)(F)C(F)(F)F,
# [16:59:47] SMILES Parse Error: Failed parsing SMILES 'CC12CCC3C(C1CCC2O)C(Cc1cc(O)ccc13)CCCCCCCCCS(=O)CCCC(F)(F)C(F)(F)F,' for input: 'CC12CCC3C(C1CCC2O)C(Cc1cc(O)ccc13)CCCCCCCCCS(=O)CCCC(F)(F)C(F)(F)F,'
# [16:59:48] SMILES Parse Error: syntax error while parsing: NNC(=O)CNC(=O)\C=N\#N
# [16:59:48] SMILES Parse Error: Failed parsing SMILES 'NNC(=O)CNC(=O)\C=N\#N' for input: 'NNC(=O)CNC(=O)\C=N\#N'
# [16:59:48] SMILES Parse Error: syntax error while parsing: O=C1NC(=O)\C(=N/#N)\C=N1
# [16:59:48] SMILES Parse Error: Failed parsing SMILES 'O=C1NC(=O)\C(=N/#N)\C=N1' for input: 'O=C1NC(=O)\C(=N/#N)\C=N1'
# [16:59:48] SMILES Parse Error: syntax error while parsing: NC(=O)CNC(=O)\C=N\#N
# [16:59:48] SMILES Parse Error: Failed parsing SMILES 'NC(=O)CNC(=O)\C=N\#N' for input: 'NC(=O)CNC(=O)\C=N\#N'
# [16:59:48] SMILES Parse Error: syntax error while parsing: CCCCN(CC(O)C1=C\C(=N/#N)\C(=O)C=C1)N=O
# [16:59:48] SMILES Parse Error: Failed parsing SMILES 'CCCCN(CC(O)C1=C\C(=N/#N)\C(=O)C=C1)N=O' for input: 'CCCCN(CC(O)C1=C\C(=N/#N)\C(=O)C=C1)N=O'
# [16:59:48] SMILES Parse Error: syntax error while parsing: NC(COC(=O)\C=N/#N)C(=O)O
# [16:59:48] SMILES Parse Error: Failed parsing SMILES 'NC(COC(=O)\C=N/#N)C(=O)O' for input: 'NC(COC(=O)\C=N/#N)C(=O)O'
# [16:59:48] SMILES Parse Error: syntax error while parsing: CCN(CC(O)C1=CC(=O)\C(=N\#N)\C=C1)N=O
# [16:59:48] SMILES Parse Error: Failed parsing SMILES 'CCN(CC(O)C1=CC(=O)\C(=N\#N)\C=C1)N=O' for input: 'CCN(CC(O)C1=CC(=O)\C(=N\#N)\C=C1)N=O'
# [16:59:49] Can't kekulize mol.  Unkekulized atoms: 0 4 7 8 9

# %%
def gridsearch(data):
    estimator = XGBClassifier(
        objective='binary:logistic',
        tree_method='gpu_hist',
        seed=42
    )
    parameters = {
        'n_estimators': [100],
        'max_depth': list(range(2, 10, 1)),
        'learning_rate': [0.1, 0.01, 0.05],
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
    }
    grid_search = TuneSearchCV(
        estimator=estimator,
        param_distributions=parameters,
        n_trials=500,
        early_stopping=True,
        #param_grid=parameters,
        scoring='roc_auc',
        use_gpu=True,
        n_jobs=6,
        search_optimization='bayesian',
        # resources_per_trial={'gpu': 1},
        cv=5,  #predefied_split(),
        verbose=3
    )
    return grid_search.fit(np.vstack(data['X'].values),np.vstack(data['y'].values))

# %%
#ames_grid = gridsearch(ames)
er_grid = gridsearch(er)
# Out:
# /home/sergeyadmin/miniconda3/lib/python3.9/site-packages/tune_sklearn/tune_basesearch.py:439: UserWarning: early_stopping is enabled but max_iters = 1. To enable partial training, set max_iters > 1.
#   warnings.warn(
# /home/sergeyadmin/miniconda3/lib/python3.9/site-packages/tune_sklearn/tune_basesearch.py:444: UserWarning: tune-sklearn implements incremental learning for xgboost models following this: https://github.com/dmlc/xgboost/issues/1686. This may negatively impact performance. To disable, set `early_stopping=False`.
#   warnings.warn(
# == Status ==<br>Current time: 2022-12-06 10:31:38 (running for 00:30:41.83)<br>Memory usage on this node: 12.2/31.3 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 1.000: 0.7048087501191741<br>Resources requested: 5.0/6 CPUs, 0.8500000000000001/1 GPUs, 0.0/14.62 GiB heap, 0.0/7.31 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/sergeyadmin/ray_results/_Trainable_2022-12-06_10-00-56<br>Number of trials: 87/300 (1 PENDING, 5 RUNNING, 81 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc                   </th><th style="text-align: right;">  colsample_bytree</th><th style="text-align: right;">  gamma</th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  max_depth</th><th style="text-align: right;">  min_child_weight</th><th style="text-align: right;">  n_estimators</th><th style="text-align: right;">  subsample</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  split0_test_score</th><th style="text-align: right;">  split1_test_score</th><th style="text-align: right;">  split2_test_score</th></tr>
# </thead>
# <tbody>
# <tr><td>_Trainable_71ad8770</td><td>RUNNING   </td><td>131.130.129.247:868507</td><td style="text-align: right;">               0.8</td><td style="text-align: right;">    1  </td><td style="text-align: right;">           0.05</td><td style="text-align: right;">          9</td><td style="text-align: right;">                 5</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.6</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_8363344c</td><td>RUNNING   </td><td>131.130.129.247:868503</td><td style="text-align: right;">               0.8</td><td style="text-align: right;">    1  </td><td style="text-align: right;">           0.05</td><td style="text-align: right;">          9</td><td style="text-align: right;">                 5</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.6</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_85e69420</td><td>RUNNING   </td><td>131.130.129.247:868509</td><td style="text-align: right;">               0.8</td><td style="text-align: right;">    1  </td><td style="text-align: right;">           0.05</td><td style="text-align: right;">          9</td><td style="text-align: right;">                 5</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.6</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_955ea564</td><td>RUNNING   </td><td>131.130.129.247:868505</td><td style="text-align: right;">               0.8</td><td style="text-align: right;">    1  </td><td style="text-align: right;">           0.1 </td><td style="text-align: right;">          8</td><td style="text-align: right;">                 5</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.6</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_a959d3ea</td><td>RUNNING   </td><td>131.130.129.247:868475</td><td style="text-align: right;">               1  </td><td style="text-align: right;">    1  </td><td style="text-align: right;">           0.05</td><td style="text-align: right;">          7</td><td style="text-align: right;">                 5</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.6</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_b0a8e550</td><td>PENDING   </td><td>                      </td><td style="text-align: right;">               1  </td><td style="text-align: right;">    1  </td><td style="text-align: right;">           0.05</td><td style="text-align: right;">          7</td><td style="text-align: right;">                 5</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.6</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_03e0252e</td><td>TERMINATED</td><td>131.130.129.247:868505</td><td style="text-align: right;">               0.8</td><td style="text-align: right;">    1.5</td><td style="text-align: right;">           0.05</td><td style="text-align: right;">          9</td><td style="text-align: right;">                 1</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.6</td><td style="text-align: right;">     1</td><td style="text-align: right;">        185.107 </td><td style="text-align: right;">           0.690674</td><td style="text-align: right;">           0.687518</td><td style="text-align: right;">           0.730188</td></tr>
# <tr><td>_Trainable_04d52ff0</td><td>TERMINATED</td><td>131.130.129.247:868505</td><td style="text-align: right;">               1  </td><td style="text-align: right;">    1.5</td><td style="text-align: right;">           0.05</td><td style="text-align: right;">          9</td><td style="text-align: right;">                 5</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.8</td><td style="text-align: right;">     1</td><td style="text-align: right;">        154.949 </td><td style="text-align: right;">           0.692321</td><td style="text-align: right;">           0.694598</td><td style="text-align: right;">           0.726721</td></tr>
# <tr><td>_Trainable_086218ea</td><td>TERMINATED</td><td>131.130.129.247:868503</td><td style="text-align: right;">               1  </td><td style="text-align: right;">    1.5</td><td style="text-align: right;">           0.05</td><td style="text-align: right;">          9</td><td style="text-align: right;">                 5</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.6</td><td style="text-align: right;">     1</td><td style="text-align: right;">        144.543 </td><td style="text-align: right;">           0.690679</td><td style="text-align: right;">           0.694409</td><td style="text-align: right;">           0.727335</td></tr>
# <tr><td>_Trainable_0c9b60e4</td><td>TERMINATED</td><td>131.130.129.247:868509</td><td style="text-align: right;">               0.8</td><td style="text-align: right;">    1.5</td><td style="text-align: right;">           0.01</td><td style="text-align: right;">          6</td><td style="text-align: right;">                 1</td><td style="text-align: right;">           100</td><td style="text-align: right;">        0.8</td><td style="text-align: right;">     1</td><td style="text-align: right;">        145.16  </td><td style="text-align: right;">
# Result for _Trainable_7fcc542a:
#   average_test_score: 0.681839684569535
#   date: 2022-12-06_10-01-30
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.681839684569535
#   pid: 868503
#   split0_test_score: 0.6600995793630354
#   split1_test_score: 0.6704855447773295
#   split2_test_score: 0.68959424271039
#   split3_test_score: 0.7089175513396477
#   split4_test_score: 0.6801015046572726
#   time_since_restore: 30.25159788131714
#   time_this_iter_s: 30.25159788131714
#   time_total_s: 30.25159788131714
#   timestamp: 1670317290
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 7fcc542a
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_7fcf8b90:
#   average_test_score: 0.6949103147236958
#   date: 2022-12-06_10-01-36
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6949103147236958
#   pid: 868507
#   split0_test_score: 0.6737106666285138
#   split1_test_score: 0.6848894993370914
#   split2_test_score: 0.7129152716971412
#   split3_test_score: 0.7202859568298662
#   split4_test_score: 0.6827501791258659
#   time_since_restore: 37.11868381500244
#   time_this_iter_s: 37.11868381500244
#   time_total_s: 37.11868381500244
#   timestamp: 1670317296
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 7fcf8b90
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_7ec9efba:
#   average_test_score: 0.671669598580349
#   date: 2022-12-06_10-01-45
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.671669598580349
#   pid: 868475
#   split0_test_score: 0.6482542612146012
#   split1_test_score: 0.6641998359420457
#   split2_test_score: 0.6867816503085625
#   split3_test_score: 0.6908175236787135
#   split4_test_score: 0.6682947217578218
#   time_since_restore: 47.5616238117218
#   time_this_iter_s: 47.5616238117218
#   time_total_s: 47.5616238117218
#   timestamp: 1670317305
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 7ec9efba
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_7fce0f22:
#   average_test_score: 0.6951052522818186
#   date: 2022-12-06_10-01-47
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6951052522818186
#   pid: 868505
#   split0_test_score: 0.67471933690064
#   split1_test_score: 0.6821174445112121
#   split2_test_score: 0.7031731383714387
#   split3_test_score: 0.7218490380671683
#   split4_test_score: 0.6936673035586338
#   time_since_restore: 47.317283630371094
#   time_this_iter_s: 47.317283630371094
#   time_total_s: 47.317283630371094
#   timestamp: 1670317307
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 7fce0f22
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_7fd0e2ba:
#   average_test_score: 0.7021389590196527
#   date: 2022-12-06_10-02-08
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7021389590196527
#   pid: 868509
#   split0_test_score: 0.6832739577073855
#   split1_test_score: 0.6859565914098492
#   split2_test_score: 0.7125504335136064
#   split3_test_score: 0.7278414456176495
#   split4_test_score: 0.7010723668497731
#   time_since_restore: 68.35186433792114
#   time_this_iter_s: 68.35186433792114
#   time_total_s: 68.35186433792114
#   timestamp: 1670317328
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 7fd0e2ba
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_7fd2db4c:
#   average_test_score: 0.6944153426986951
#   date: 2022-12-06_10-02-33
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6944153426986951
#   pid: 868503
#   split0_test_score: 0.6763909157676862
#   split1_test_score: 0.6769763260556462
#   split2_test_score: 0.7134661058173807
#   split3_test_score: 0.7215402371209737
#   split4_test_score: 0.6837031287317888
#   time_since_restore: 63.35406255722046
#   time_this_iter_s: 63.35406255722046
#   time_total_s: 63.35406255722046
#   timestamp: 1670317353
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 7fd2db4c
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_92d8a0a0:
#   average_test_score: 0.7015475103978065
#   date: 2022-12-06_10-02-42
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7015475103978065
#   pid: 868507
#   split0_test_score: 0.6935633483083907
#   split1_test_score: 0.6863464675079406
#   split2_test_score: 0.7216022357665416
#   split3_test_score: 0.7114201505136349
#   split4_test_score: 0.6948053498925244
#   time_since_restore: 65.82935762405396
#   time_this_iter_s: 65.82935762405396
#   time_total_s: 65.82935762405396
#   timestamp: 1670317362
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 92d8a0a0
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_96f875e8:
#   average_test_score: 0.7005794382092813
#   date: 2022-12-06_10-02-58
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7005794382092813
#   pid: 868475
#   split0_test_score: 0.6909939813622533
#   split1_test_score: 0.6879333943781536
#   split2_test_score: 0.7227873637222079
#   split3_test_score: 0.7114571112446466
#   split4_test_score: 0.689725340339145
#   time_since_restore: 72.73526787757874
#   time_this_iter_s: 72.73526787757874
#   time_total_s: 72.73526787757874
#   timestamp: 1670317378
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 96f875e8
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_9c27494a:
#   average_test_score: 0.6805088378704197
#   date: 2022-12-06_10-03-18
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6805088378704197
#   pid: 868505
#   split0_test_score: 0.6634498907870012
#   split1_test_score: 0.6681856334830839
#   split2_test_score: 0.698590007725985
#   split3_test_score: 0.7080996461308077
#   split4_test_score: 0.6642190112252209
#   time_since_restore: 91.41878628730774
#   time_this_iter_s: 91.41878628730774
#   time_total_s: 91.41878628730774
#   timestamp: 1670317398
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9c27494a
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_9d0bb896:
#   average_test_score: 0.6961954505849267
#   date: 2022-12-06_10-03-21
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6961954505849267
#   pid: 868509
#   split0_test_score: 0.6824775135681651
#   split1_test_score: 0.6802002556251849
#   split2_test_score: 0.7169797598267853
#   split3_test_score: 0.7227885560038533
#   split4_test_score: 0.6785311679006448
#   time_since_restore: 73.02958154678345
#   time_this_iter_s: 73.02958154678345
#   time_total_s: 73.02958154678345
#   timestamp: 1670317401
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9d0bb896
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_c783c0d2:
#   average_test_score: 0.6739131656203166
#   date: 2022-12-06_10-03-46
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6739131656203166
#   pid: 868505
#   split0_test_score: 0.6452795185089802
#   split1_test_score: 0.6580834311004282
#   split2_test_score: 0.6830760389542259
#   split3_test_score: 0.7014944058145192
#   split4_test_score: 0.6816324337234296
#   time_since_restore: 27.81191110610962
#   time_this_iter_s: 27.81191110610962
#   time_total_s: 27.81191110610962
#   timestamp: 1670317426
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c783c0d2
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_d38af3a0:
#   average_test_score: 0.6969318896190516
#   date: 2022-12-06_10-04-07
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6969318896190516
#   pid: 868509
#   split0_test_score: 0.680671206875173
#   split1_test_score: 0.6871047586345037
#   split2_test_score: 0.709491038811152
#   split3_test_score: 0.7142828187445751
#   split4_test_score: 0.6931096250298543
#   time_since_restore: 46.296836137771606
#   time_this_iter_s: 46.296836137771606
#   time_total_s: 46.296836137771606
#   timestamp: 1670317447
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d38af3a0
#   warmup_time: 0.019457340240478516
# Result for _Trainable_a999dc8c:
#   average_test_score: 0.7001643034044113
#   date: 2022-12-06_10-04-13
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7001643034044113
#   pid: 868503
#   split0_test_score: 0.6819552942074187
#   split1_test_score: 0.6788601310555985
#   split2_test_score: 0.717190793678046
#   split3_test_score: 0.7300221287473413
#   split4_test_score: 0.6927931693336518
#   time_since_restore: 99.7350549697876
#   time_this_iter_s: 99.7350549697876
#   time_total_s: 99.7350549697876
#   timestamp: 1670317453
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a999dc8c
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_be34d5a2:
#   average_test_score: 0.6967668330024571
#   date: 2022-12-06_10-04-17
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6967668330024571
#   pid: 868475
#   split0_test_score: 0.682625356492212
#   split1_test_score: 0.6797459963182343
#   split2_test_score: 0.7128377733901813
#   split3_test_score: 0.7201750746368311
#   split4_test_score: 0.6884499641748267
#   time_since_restore: 79.0082619190216
#   time_this_iter_s: 79.0082619190216
#   time_total_s: 79.0082619190216
#   timestamp: 1670317457
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: be34d5a2
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_b89deca0:
#   average_test_score: 0.6791419416908747
#   date: 2022-12-06_10-04-30
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6791419416908747
#   pid: 868507
#   split0_test_score: 0.663654963230034
#   split1_test_score: 0.6725338846443663
#   split2_test_score: 0.7035832832575042
#   split3_test_score: 0.6964403239190774
#   split4_test_score: 0.6594972534033914
#   time_since_restore: 108.16079807281494
#   time_this_iter_s: 108.16079807281494
#   time_total_s: 108.16079807281494
#   timestamp: 1670317470
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: b89deca0
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_d5555914:
#   average_test_score: 0.6953622333360299
#   date: 2022-12-06_10-04-53
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6953622333360299
#   pid: 868505
#   split0_test_score: 0.6836352190459839
#   split1_test_score: 0.6814700355776844
#   split2_test_score: 0.7117659121908413
#   split3_test_score: 0.7223223738804475
#   split4_test_score: 0.6776176259851923
#   time_since_restore: 67.16883683204651
#   time_this_iter_s: 67.16883683204651
#   time_total_s: 67.16883683204651
#   timestamp: 1670317493
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d5555914
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_e4573d74:
#   average_test_score: 0.7028301725049922
#   date: 2022-12-06_10-05-38
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7028301725049922
#   pid: 868509
#   split0_test_score: 0.6917916177831192
#   split1_test_score: 0.6898148148148148
#   split2_test_score: 0.72180850049122
#   split3_test_score: 0.7219372669089383
#   split4_test_score: 0.6887986625268688
#   time_since_restore: 90.62066578865051
#   time_this_iter_s: 90.62066578865051
#   time_total_s: 90.62066578865051
#   timestamp: 1670317538
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e4573d74
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_f1246d10:
#   average_test_score: 0.7021605555839516
#   date: 2022-12-06_10-05-39
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7021605555839516
#   pid: 868503
#   split0_test_score: 0.691740349672361
#   split1_test_score: 0.6906207972071996
#   split2_test_score: 0.7215605059089478
#   split3_test_score: 0.7189351017254699
#   split4_test_score: 0.6879460234057798
#   time_since_restore: 85.61444783210754
#   time_this_iter_s: 85.61444783210754
#   time_total_s: 85.61444783210754
#   timestamp: 1670317539
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f1246d10
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_f44f6f76:
#   average_test_score: 0.7021605555839516
#   date: 2022-12-06_10-05-43
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7021605555839516
#   pid: 868475
#   split0_test_score: 0.691740349672361
#   split1_test_score: 0.6906207972071996
#   split2_test_score: 0.7215605059089478
#   split3_test_score: 0.7189351017254699
#   split4_test_score: 0.6879460234057798
#   time_since_restore: 86.01184344291687
#   time_this_iter_s: 86.01184344291687
#   time_total_s: 86.01184344291687
#   timestamp: 1670317543
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f44f6f76
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_feeae744:
#   average_test_score: 0.7003190224499247
#   date: 2022-12-06_10-07-08
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7003190224499247
#   pid: 868505
#   split0_test_score: 0.6898005074350684
#   split1_test_score: 0.6842075142358429
#   split2_test_score: 0.7201178451178452
#   split3_test_score: 0.7155525986970747
#   split4_test_score: 0.6919166467637927
#   time_since_restore: 134.1696014404297
#   time_this_iter_s: 134.1696014404297
#   time_total_s: 134.1696014404297
#   timestamp: 1670317628
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: feeae744
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_0c9b60e4:
#   average_test_score: 0.682926548639224
#   date: 2022-12-06_10-08-04
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.682926548639224
#   pid: 868509
#   split0_test_score: 0.6597144723915261
#   split1_test_score: 0.669275378907107
#   split2_test_score: 0.6991086502417947
#   split3_test_score: 0.7110135824725059
#   split4_test_score: 0.675520659183186
#   time_since_restore: 145.16006422042847
#   time_this_iter_s: 145.16006422042847
#   time_total_s: 145.16006422042847
#   timestamp: 1670317684
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 0c9b60e4
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_f6d4e2bc:
#   average_test_score: 0.6911697817833794
#   date: 2022-12-06_10-08-13
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6911697817833794
#   pid: 868507
#   split0_test_score: 0.675762583340487
#   split1_test_score: 0.6771480146126039
#   split2_test_score: 0.7087995154567392
#   split3_test_score: 0.7185034957697848
#   split4_test_score: 0.6756352997372821
#   time_since_restore: 222.3310375213623
#   time_this_iter_s: 222.3310375213623
#   time_total_s: 222.3310375213623
#   timestamp: 1670317693
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f6d4e2bc
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_27a8bb84:
#   average_test_score: 0.7010637531123562
#   date: 2022-12-06_10-08-16
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7010637531123562
#   pid: 868475
#   split0_test_score: 0.6963020192481949
#   split1_test_score: 0.6868496103623583
#   split2_test_score: 0.72230568193741
#   split3_test_score: 0.7018210909853969
#   split4_test_score: 0.6980403630284213
#   time_since_restore: 151.9520492553711
#   time_this_iter_s: 151.9520492553711
#   time_total_s: 151.9520492553711
#   timestamp: 1670317696
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 27a8bb84
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_5cdc3f06:
#   average_test_score: 0.6851349447841868
#   date: 2022-12-06_10-08-43
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6851349447841868
#   pid: 868509
#   split0_test_score: 0.6672401541381712
#   split1_test_score: 0.6724325407044953
#   split2_test_score: 0.6955091519539112
#   split3_test_score: 0.7223378735418395
#   split4_test_score: 0.6681550035825172
#   time_since_restore: 38.513583183288574
#   time_this_iter_s: 38.513583183288574
#   time_total_s: 38.513583183288574
#   timestamp: 1670317723
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 5cdc3f06
#   warmup_time: 0.019457340240478516
# Result for _Trainable_7e3abaa6:
#   average_test_score: 0.6851349447841868
#   date: 2022-12-06_10-08-51
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6851349447841868
#   pid: 868507
#   split0_test_score: 0.6672401541381712
#   split1_test_score: 0.6724325407044953
#   split2_test_score: 0.6955091519539112
#   split3_test_score: 0.7223378735418395
#   split4_test_score: 0.6681550035825172
#   time_since_restore: 36.81596922874451
#   time_this_iter_s: 36.81596922874451
#   time_total_s: 36.81596922874451
#   timestamp: 1670317731
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 7e3abaa6
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_83caaeb8:
#   average_test_score: 0.6851349447841868
#   date: 2022-12-06_10-08-53
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6851349447841868
#   pid: 868475
#   split0_test_score: 0.6672401541381712
#   split1_test_score: 0.6724325407044953
#   split2_test_score: 0.6955091519539112
#   split3_test_score: 0.7223378735418395
#   split4_test_score: 0.6681550035825172
#   time_since_restore: 36.4242947101593
#   time_this_iter_s: 36.4242947101593
#   time_total_s: 36.4242947101593
#   timestamp: 1670317733
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 83caaeb8
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_2a5316a4:
#   average_test_score: 0.7010637531123562
#   date: 2022-12-06_10-09-17
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7010637531123562
#   pid: 868505
#   split0_test_score: 0.6963020192481949
#   split1_test_score: 0.6868496103623583
#   split2_test_score: 0.72230568193741
#   split3_test_score: 0.7018210909853969
#   split4_test_score: 0.6980403630284213
#   time_since_restore: 128.56050324440002
#   time_this_iter_s: 128.56050324440002
#   time_total_s: 128.56050324440002
#   timestamp: 1670317757
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2a5316a4
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_852cf43c:
#   average_test_score: 0.6869665956979171
#   date: 2022-12-06_10-09-22
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6869665956979171
#   pid: 868509
#   split0_test_score: 0.6717279022519815
#   split1_test_score: 0.6731097566791617
#   split2_test_score: 0.6984063963525721
#   split3_test_score: 0.717195562804628
#   split4_test_score: 0.6743933604012419
#   time_since_restore: 38.171074628829956
#   time_this_iter_s: 38.171074628829956
#   time_total_s: 38.171074628829956
#   timestamp: 1670317762
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 852cf43c
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_276b3c5a:
#   average_test_score: 0.6921175126321544
#   date: 2022-12-06_10-09-31
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6921175126321544
#   pid: 868503
#   split0_test_score: 0.6769179042550147
#   split1_test_score: 0.6760236930208602
#   split2_test_score: 0.7099894125389876
#   split3_test_score: 0.7186763766083879
#   split4_test_score: 0.678980176737521
#   time_since_restore: 232.16181206703186
#   time_this_iter_s: 232.16181206703186
#   time_total_s: 232.16181206703186
#   timestamp: 1670317771
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 276b3c5a
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_95747dc4:
#   average_test_score: 0.7027865337005472
#   date: 2022-12-06_10-09-47
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7027865337005472
#   pid: 868507
#   split0_test_score: 0.6914899705267977
#   split1_test_score: 0.6922589921881707
#   split2_test_score: 0.7207390238551712
#   split3_test_score: 0.7214031247317366
#   split4_test_score: 0.6880415572008598
#   time_since_restore: 56.109540939331055
#   time_this_iter_s: 56.109540939331055
#   time_total_s: 56.109540939331055
#   timestamp: 1670317787
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 95747dc4
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_9a04ffbc:
#   average_test_score: 0.7027865337005472
#   date: 2022-12-06_10-09-49
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7027865337005472
#   pid: 868475
#   split0_test_score: 0.6914899705267977
#   split1_test_score: 0.6922589921881707
#   split2_test_score: 0.7207390238551712
#   split3_test_score: 0.7214031247317366
#   split4_test_score: 0.6880415572008598
#   time_since_restore: 55.6574330329895
#   time_this_iter_s: 55.6574330329895
#   time_total_s: 55.6574330329895
#   timestamp: 1670317789
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9a04ffbc
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_a9c87c12:
#   average_test_score: 0.7027865337005472
#   date: 2022-12-06_10-10-18
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7027865337005472
#   pid: 868509
#   split0_test_score: 0.6914899705267977
#   split1_test_score: 0.6922589921881707
#   split2_test_score: 0.7207390238551712
#   split3_test_score: 0.7214031247317366
#   split4_test_score: 0.6880415572008598
#   time_since_restore: 56.28604507446289
#   time_this_iter_s: 56.28604507446289
#   time_total_s: 56.28604507446289
#   timestamp: 1670317818
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a9c87c12
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_9b2d7b08:
#   average_test_score: 0.7058472106863919
#   date: 2022-12-06_10-10-50
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7058472106863919
#   pid: 868505
#   split0_test_score: 0.6880144695300503
#   split1_test_score: 0.6948462433589913
#   split2_test_score: 0.7318677807346363
#   split3_test_score: 0.7261817895670586
#   split4_test_score: 0.6883257702412228
#   time_since_restore: 92.17344570159912
#   time_this_iter_s: 92.17344570159912
#   time_total_s: 92.17344570159912
#   timestamp: 1670317850
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9b2d7b08
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_ac7d202a:
#   average_test_score: 0.7074767038964485
#   date: 2022-12-06_10-10-56
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7074767038964485
#   pid: 868503
#   split0_test_score: 0.6888609894983833
#   split1_test_score: 0.6967956238494483
#   split2_test_score: 0.7267075857727415
#   split3_test_score: 0.723509886399405
#   split4_test_score: 0.7015094339622642
#   time_since_restore: 84.09751653671265
#   time_this_iter_s: 84.09751653671265
#   time_total_s: 84.09751653671265
#   timestamp: 1670317856
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ac7d202a
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_b253c53a:
#   average_test_score: 0.7074767038964485
#   date: 2022-12-06_10-11-14
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7074767038964485
#   pid: 868507
#   split0_test_score: 0.6888609894983833
#   split1_test_score: 0.6967956238494483
#   split2_test_score: 0.7267075857727415
#   split3_test_score: 0.723509886399405
#   split4_test_score: 0.7015094339622642
#   time_since_restore: 86.10171627998352
#   time_this_iter_s: 86.10171627998352
#   time_total_s: 86.10171627998352
#   timestamp: 1670317874
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: b253c53a
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_bbbf29ca:
#   average_test_score: 0.7074767038964485
#   date: 2022-12-06_10-11-15
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7074767038964485
#   pid: 868475
#   split0_test_score: 0.6888609894983833
#   split1_test_score: 0.6967956238494483
#   split2_test_score: 0.7267075857727415
#   split3_test_score: 0.723509886399405
#   split4_test_score: 0.7015094339622642
#   time_since_restore: 85.43847489356995
#   time_this_iter_s: 85.43847489356995
#   time_total_s: 85.43847489356995
#   timestamp: 1670317875
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: bbbf29ca
#   warmup_time: 0.018968820571899414
# Result for _Trainable_bcac0ea2:
#   average_test_score: 0.7074767038964485
#   date: 2022-12-06_10-11-48
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7074767038964485
#   pid: 868509
#   split0_test_score: 0.6888609894983833
#   split1_test_score: 0.6967956238494483
#   split2_test_score: 0.7267075857727415
#   split3_test_score: 0.723509886399405
#   split4_test_score: 0.7015094339622642
#   time_since_restore: 89.2468056678772
#   time_this_iter_s: 89.2468056678772
#   time_total_s: 89.2468056678772
#   timestamp: 1670317908
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: bcac0ea2
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_ce599aac:
#   average_test_score: 0.7074767038964485
#   date: 2022-12-06_10-12-24
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7074767038964485
#   pid: 868505
#   split0_test_score: 0.6888609894983833
#   split1_test_score: 0.6967956238494483
#   split2_test_score: 0.7267075857727415
#   split3_test_score: 0.723509886399405
#   split4_test_score: 0.7015094339622642
#   time_since_restore: 93.81737780570984
#   time_this_iter_s: 93.81737780570984
#   time_total_s: 93.81737780570984
#   timestamp: 1670317944
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ce599aac
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_e10ac54a:
#   average_test_score: 0.7074767038964485
#   date: 2022-12-06_10-12-32
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7074767038964485
#   pid: 868503
#   split0_test_score: 0.6888609894983833
#   split1_test_score: 0.6967956238494483
#   split2_test_score: 0.7267075857727415
#   split3_test_score: 0.723509886399405
#   split4_test_score: 0.7015094339622642
#   time_since_restore: 95.82591342926025
#   time_this_iter_s: 95.82591342926025
#   time_total_s: 95.82591342926025
#   timestamp: 1670317952
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e10ac54a
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_e4c1b13a:
#   average_test_score: 0.7048087501191741
#   date: 2022-12-06_10-14-16
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7048087501191741
#   pid: 868507
#   split0_test_score: 0.6906744498812487
#   split1_test_score: 0.6875184803655059
#   split2_test_score: 0.730187855896071
#   split3_test_score: 0.7250252763708855
#   split4_test_score: 0.6906376880821591
#   time_since_restore: 181.75030827522278
#   time_this_iter_s: 181.75030827522278
#   time_total_s: 181.75030827522278
#   timestamp: 1670318056
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e4c1b13a
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_ef66303e:
#   average_test_score: 0.7048087501191741
#   date: 2022-12-06_10-14-17
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7048087501191741
#   pid: 868475
#   split0_test_score: 0.6906744498812487
#   split1_test_score: 0.6875184803655059
#   split2_test_score: 0.730187855896071
#   split3_test_score: 0.7250252763708855
#   split4_test_score: 0.6906376880821591
#   time_since_restore: 181.52190113067627
#   time_this_iter_s: 181.52190113067627
#   time_total_s: 181.52190113067627
#   timestamp: 1670318057
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ef66303e
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_efe5dbf4:
#   average_test_score: 0.7048087501191741
#   date: 2022-12-06_10-14-54
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7048087501191741
#   pid: 868509
#   split0_test_score: 0.6906744498812487
#   split1_test_score: 0.6875184803655059
#   split2_test_score: 0.730187855896071
#   split3_test_score: 0.7250252763708855
#   split4_test_score: 0.6906376880821591
#   time_since_restore: 185.2929229736328
#   time_this_iter_s: 185.2929229736328
#   time_total_s: 185.2929229736328
#   timestamp: 1670318094
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: efe5dbf4
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_03e0252e:
#   average_test_score: 0.7048087501191741
#   date: 2022-12-06_10-15-30
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7048087501191741
#   pid: 868505
#   split0_test_score: 0.6906744498812487
#   split1_test_score: 0.6875184803655059
#   split2_test_score: 0.730187855896071
#   split3_test_score: 0.7250252763708855
#   split4_test_score: 0.6906376880821591
#   time_since_restore: 185.10690808296204
#   time_this_iter_s: 185.10690808296204
#   time_total_s: 185.10690808296204
#   timestamp: 1670318130
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 03e0252e
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_1946a51e:
#   average_test_score: 0.7048087501191741
#   date: 2022-12-06_10-15-38
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7048087501191741
#   pid: 868503
#   split0_test_score: 0.6906744498812487
#   split1_test_score: 0.6875184803655059
#   split2_test_score: 0.730187855896071
#   split3_test_score: 0.7250252763708855
#   split4_test_score: 0.6906376880821591
#   time_since_restore: 185.11405158042908
#   time_this_iter_s: 185.11405158042908
#   time_total_s: 185.11405158042908
#   timestamp: 1670318138
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1946a51e
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_5c6a041c:
#   average_test_score: 0.7014193694042823
#   date: 2022-12-06_10-16-13
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7014193694042823
#   pid: 868509
#   split0_test_score: 0.6865193483465439
#   split1_test_score: 0.6933093923178909
#   split2_test_score: 0.722557253364619
#   split3_test_score: 0.7169666447286844
#   split4_test_score: 0.6877442082636733
#   time_since_restore: 78.04997706413269
#   time_this_iter_s: 78.04997706413269
#   time_total_s: 78.04997706413269
#   timestamp: 1670318173
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 5c6a041c
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_5c0accb8:
#   average_test_score: 0.7008889113073147
#   date: 2022-12-06_10-16-28
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7008889113073147
#   pid: 868475
#   split0_test_score: 0.6805722474985931
#   split1_test_score: 0.6886773781249702
#   split2_test_score: 0.7231271639911866
#   split3_test_score: 0.7247379364943105
#   split4_test_score: 0.6873298304275137
#   time_since_restore: 130.41767144203186
#   time_this_iter_s: 130.41767144203186
#   time_total_s: 130.41767144203186
#   timestamp: 1670318188
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 5c0accb8
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_1e36ff06:
#   average_test_score: 0.7048087501191741
#   date: 2022-12-06_10-17-12
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7048087501191741
#   pid: 868507
#   split0_test_score: 0.6906744498812487
#   split1_test_score: 0.6875184803655059
#   split2_test_score: 0.730187855896071
#   split3_test_score: 0.7250252763708855
#   split4_test_score: 0.6906376880821591
#   time_since_restore: 175.86956024169922
#   time_this_iter_s: 175.86956024169922
#   time_total_s: 175.86956024169922
#   timestamp: 1670318232
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1e36ff06
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_8ce44f62:
#   average_test_score: 0.7014193694042823
#   date: 2022-12-06_10-17-31
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7014193694042823
#   pid: 868509
#   split0_test_score: 0.6865193483465439
#   split1_test_score: 0.6933093923178909
#   split2_test_score: 0.722557253364619
#   split3_test_score: 0.7169666447286844
#   split4_test_score: 0.6877442082636733
#   time_since_restore: 77.37154698371887
#   time_this_iter_s: 77.37154698371887
#   time_total_s: 77.37154698371887
#   timestamp: 1670318251
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8ce44f62
#   warmup_time: 0.019457340240478516
# Result for _Trainable_72a75f90:
#   average_test_score: 0.7008889113073147
#   date: 2022-12-06_10-17-36
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7008889113073147
#   pid: 868505
#   split0_test_score: 0.6805722474985931
#   split1_test_score: 0.6886773781249702
#   split2_test_score: 0.7231271639911866
#   split3_test_score: 0.7247379364943105
#   split4_test_score: 0.6873298304275137
#   time_since_restore: 126.24018406867981
#   time_this_iter_s: 126.24018406867981
#   time_total_s: 126.24018406867981
#   timestamp: 1670318256
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 72a75f90
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_87ef9250:
#   average_test_score: 0.7008889113073147
#   date: 2022-12-06_10-17-45
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7008889113073147
#   pid: 868503
#   split0_test_score: 0.6805722474985931
#   split1_test_score: 0.6886773781249702
#   split2_test_score: 0.7231271639911866
#   split3_test_score: 0.7247379364943105
#   split4_test_score: 0.6873298304275137
#   time_since_restore: 126.92799115180969
#   time_this_iter_s: 126.92799115180969
#   time_total_s: 126.92799115180969
#   timestamp: 1670318265
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 87ef9250
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_a185b28a:
#   average_test_score: 0.6966634473319517
#   date: 2022-12-06_10-17-52
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6966634473319517
#   pid: 868475
#   split0_test_score: 0.6774270085176601
#   split1_test_score: 0.680507864289734
#   split2_test_score: 0.71432693316546
#   split3_test_score: 0.7328180292061313
#   split4_test_score: 0.6782374014807738
#   time_since_restore: 84.04341578483582
#   time_this_iter_s: 84.04341578483582
#   time_total_s: 84.04341578483582
#   timestamp: 1670318272
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a185b28a
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_aa7f4a5e:
#   average_test_score: 0.6953682138162077
#   date: 2022-12-06_10-18-39
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6953682138162077
#   pid: 868507
#   split0_test_score: 0.6807296286758042
#   split1_test_score: 0.6799260308467108
#   split2_test_score: 0.7141671674249577
#   split3_test_score: 0.7288584618612945
#   split4_test_score: 0.6731597802722713
#   time_since_restore: 85.5574278831482
#   time_this_iter_s: 85.5574278831482
#   time_total_s: 85.5574278831482
#   timestamp: 1670318319
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: aa7f4a5e
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_c533c870:
#   average_test_score: 0.6966634473319517
#   date: 2022-12-06_10-18-59
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6966634473319517
#   pid: 868509
#   split0_test_score: 0.6774270085176601
#   split1_test_score: 0.680507864289734
#   split2_test_score: 0.71432693316546
#   split3_test_score: 0.7328180292061313
#   split4_test_score: 0.6782374014807738
#   time_since_restore: 87.86534380912781
#   time_this_iter_s: 87.86534380912781
#   time_total_s: 87.86534380912781
#   timestamp: 1670318339
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c533c870
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_d000f804:
#   average_test_score: 0.6966634473319517
#   date: 2022-12-06_10-19-05
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
# ...
#   split1_test_score: 0.694598248776719
#   split2_test_score: 0.7267207008708425
#   split3_test_score: 0.725298308867714
#   split4_test_score: 0.6889133030809649
#   time_since_restore: 154.94943928718567
#   time_this_iter_s: 154.94943928718567
#   time_total_s: 154.94943928718567
#   timestamp: 1670318501
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 04d52ff0
#   warmup_time: 0.02291250228881836
# Result for _Trainable_0e82e920:
#   average_test_score: 0.7055703104859958
#   date: 2022-12-06_10-21-58
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7055703104859958
#   pid: 868475
#   split0_test_score: 0.6923209908337388
#   split1_test_score: 0.694598248776719
#   split2_test_score: 0.7267207008708425
#   split3_test_score: 0.725298308867714
#   split4_test_score: 0.6889133030809649
#   time_since_restore: 154.7320671081543
#   time_this_iter_s: 154.7320671081543
#   time_total_s: 154.7320671081543
#   timestamp: 1670318518
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 0e82e920
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_129a09a8:
#   average_test_score: 0.7086151508119133
#   date: 2022-12-06_10-22-52
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7086151508119133
#   pid: 868507
#   split0_test_score: 0.6906792190078309
#   split1_test_score: 0.6944086759950783
#   split2_test_score: 0.7273347259182954
#   split3_test_score: 0.7304716189277096
#   split4_test_score: 0.700181514210652
#   time_since_restore: 137.37697339057922
#   time_this_iter_s: 137.37697339057922
#   time_total_s: 137.37697339057922
#   timestamp: 1670318572
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 129a09a8
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_3d5fd028:
#   average_test_score: 0.6992674268583818
#   date: 2022-12-06_10-23-02
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6992674268583818
#   pid: 868509
#   split0_test_score: 0.6945243273146955
#   split1_test_score: 0.6886368405490217
#   split2_test_score: 0.7185285336843411
#   split3_test_score: 0.7193070935988783
#   split4_test_score: 0.6753403391449725
#   time_since_restore: 86.60133624076843
#   time_this_iter_s: 86.60133624076843
#   time_total_s: 86.60133624076843
#   timestamp: 1670318582
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3d5fd028
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_61ca401a:
#   average_test_score: 0.6992674268583818
#   date: 2022-12-06_10-23-07
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6992674268583818
#   pid: 868503
#   split0_test_score: 0.6945243273146955
#   split1_test_score: 0.6886368405490217
#   split2_test_score: 0.7185285336843411
#   split3_test_score: 0.7193070935988783
#   split4_test_score: 0.6753403391449725
#   time_since_restore: 85.99583172798157
#   time_this_iter_s: 85.99583172798157
#   time_total_s: 85.99583172798157
#   timestamp: 1670318587
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 61ca401a
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_651cebf0:
#   average_test_score: 0.7007746606916788
#   date: 2022-12-06_10-23-09
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7007746606916788
#   pid: 868505
#   split0_test_score: 0.6953935006342937
#   split1_test_score: 0.6886690321534514
#   split2_test_score: 0.7192093265039441
#   split3_test_score: 0.7193905533140661
#   split4_test_score: 0.6812108908526391
#   time_since_restore: 86.72980499267578
#   time_this_iter_s: 86.72980499267578
#   time_total_s: 86.72980499267578
#   timestamp: 1670318589
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 651cebf0
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_658b8cd6:
#   average_test_score: 0.702761758986649
#   date: 2022-12-06_10-23-33
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.702761758986649
#   pid: 868475
#   split0_test_score: 0.6989023855171164
#   split1_test_score: 0.6893534018179911
#   split2_test_score: 0.724045220858252
#   split3_test_score: 0.7179061626653696
#   split4_test_score: 0.6836016240745163
#   time_since_restore: 94.94285774230957
#   time_this_iter_s: 94.94285774230957
#   time_total_s: 94.94285774230957
#   timestamp: 1670318613
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 658b8cd6
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_6f3e6a0a:
#   average_test_score: 0.6992674268583818
#   date: 2022-12-06_10-24-22
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6992674268583818
#   pid: 868507
#   split0_test_score: 0.6945243273146955
#   split1_test_score: 0.6886368405490217
#   split2_test_score: 0.7185285336843411
#   split3_test_score: 0.7193070935988783
#   split4_test_score: 0.6753403391449725
#   time_since_restore: 89.11912989616394
#   time_this_iter_s: 89.11912989616394
#   time_total_s: 89.11912989616394
#   timestamp: 1670318662
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6f3e6a0a
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_8faf2be4:
#   average_test_score: 0.6992674268583818
#   date: 2022-12-06_10-24-34
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6992674268583818
#   pid: 868509
#   split0_test_score: 0.6945243273146955
#   split1_test_score: 0.6886368405490217
#   split2_test_score: 0.7185285336843411
#   split3_test_score: 0.7193070935988783
#   split4_test_score: 0.6753403391449725
#   time_since_restore: 90.67873430252075
#   time_this_iter_s: 90.67873430252075
#   time_total_s: 90.67873430252075
#   timestamp: 1670318674
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8faf2be4
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_95dd9c08:
#   average_test_score: 0.7038323683648678
#   date: 2022-12-06_10-25-14
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7038323683648678
#   pid: 868503
#   split0_test_score: 0.6832501120744747
#   split1_test_score: 0.6923901431691799
#   split2_test_score: 0.7243921748171039
#   split3_test_score: 0.7206555641399834
#   split4_test_score: 0.6984738476235969
#   time_since_restore: 125.96315670013428
#   time_this_iter_s: 125.96315670013428
#   time_total_s: 125.96315670013428
#   timestamp: 1670318714
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 95dd9c08
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_98d500ae:
#   average_test_score: 0.7038323683648678
#   date: 2022-12-06_10-25-16
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7038323683648678
#   pid: 868505
#   split0_test_score: 0.6832501120744747
#   split1_test_score: 0.6923901431691799
#   split2_test_score: 0.7243921748171039
#   split3_test_score: 0.7206555641399834
#   split4_test_score: 0.6984738476235969
#   time_since_restore: 126.16206574440002
#   time_this_iter_s: 126.16206574440002
#   time_total_s: 126.16206574440002
#   timestamp: 1670318716
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 98d500ae
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_99b587b4:
#   average_test_score: 0.7073072035314034
#   date: 2022-12-06_10-25-50
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7073072035314034
#   pid: 868475
#   split0_test_score: 0.6854820633149245
#   split1_test_score: 0.6980200970994171
#   split2_test_score: 0.7284876622695319
#   split3_test_score: 0.7259159107601033
#   split4_test_score: 0.6986302842130403
#   time_since_restore: 135.82595252990723
#   time_this_iter_s: 135.82595252990723
#   time_total_s: 135.82595252990723
#   timestamp: 1670318750
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 99b587b4
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_cc5eb83e:
#   average_test_score: 0.7076357095359024
#   date: 2022-12-06_10-27-40
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7076357095359024
#   pid: 868503
#   split0_test_score: 0.6967109718526148
#   split1_test_score: 0.6940819908242004
#   split2_test_score: 0.7286343129119333
#   split3_test_score: 0.714371047586345
#   split4_test_score: 0.7043802245044184
#   time_since_restore: 145.05475044250488
#   time_this_iter_s: 145.05475044250488
#   time_total_s: 145.05475044250488
#   timestamp: 1670318860
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: cc5eb83e
#   warmup_time: 0.023080825805664062
# Result for _Trainable_a851a898:
#   average_test_score: 0.6986429809310546
#   date: 2022-12-06_10-28-06
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6986429809310546
#   pid: 868507
#   split0_test_score: 0.6905325683654295
#   split1_test_score: 0.6943037552102708
#   split2_test_score: 0.7182924619185242
#   split3_test_score: 0.7069908242004559
#   split4_test_score: 0.6830952949605923
#   time_since_restore: 223.10791063308716
#   time_this_iter_s: 223.10791063308716
#   time_total_s: 223.10791063308716
#   timestamp: 1670318886
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a851a898
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_c54c87f6:
#   average_test_score: 0.6986429809310546
#   date: 2022-12-06_10-28-18
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6986429809310546
#   pid: 868509
#   split0_test_score: 0.6905325683654295
#   split1_test_score: 0.6943037552102708
#   split2_test_score: 0.7182924619185242
#   split3_test_score: 0.7069908242004559
#   split4_test_score: 0.6830952949605923
#   time_since_restore: 222.99304032325745
#   time_this_iter_s: 222.99304032325745
#   time_total_s: 222.99304032325745
#   timestamp: 1670318898
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c54c87f6
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_e46812cc:
#   average_test_score: 0.6986429809310546
#   date: 2022-12-06_10-28-57
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.6986429809310546
#   pid: 868505
#   split0_test_score: 0.6905325683654295
#   split1_test_score: 0.6943037552102708
#   split2_test_score: 0.7182924619185242
#   split3_test_score: 0.7069908242004559
#   split4_test_score: 0.6830952949605923
#   time_since_restore: 220.7419717311859
#   time_this_iter_s: 220.7419717311859
#   time_total_s: 220.7419717311859
#   timestamp: 1670318937
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e46812cc
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_e569ce68:
#   average_test_score: 0.7034085703134201
#   date: 2022-12-06_10-29-11
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7034085703134201
#   pid: 868475
#   split0_test_score: 0.6890720233496439
#   split1_test_score: 0.686800726814891
#   split2_test_score: 0.7283958565828255
#   split3_test_score: 0.7122344788775383
#   split4_test_score: 0.700539765942202
#   time_since_restore: 200.28408646583557
#   time_this_iter_s: 200.28408646583557
#   time_total_s: 200.28408646583557
#   timestamp: 1670318951
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e569ce68
#   warmup_time: 0.018968820571899414
#
# Result for _Trainable_3b5faee6:
#   average_test_score: 0.7084517438324447
#   date: 2022-12-06_10-29-41
#   done: true
#   experiment_id: 669c69307b2c41e7be55d2174981d5ad
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7084517438324447
#   pid: 868507
#   split0_test_score: 0.6910547877261758
#   split1_test_score: 0.6918345399223587
#   split2_test_score: 0.7283910874562434
#   split3_test_score: 0.7332591734149808
#   split4_test_score: 0.6977191306424647
#   time_since_restore: 94.00234532356262
#   time_this_iter_s: 94.00234532356262
#   time_total_s: 94.00234532356262
#   timestamp: 1670318981
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3b5faee6
#   warmup_time: 0.020880699157714844
#
# Result for _Trainable_f9c02394:
#   average_test_score: 0.7076357095359024
#   date: 2022-12-06_10-29-45
#   done: true
#   experiment_id: b4c888095e9841ceae107d68097526ab
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7076357095359024
#   pid: 868503
#   split0_test_score: 0.6967109718526148
#   split1_test_score: 0.6940819908242004
#   split2_test_score: 0.7286343129119333
#   split3_test_score: 0.714371047586345
#   split4_test_score: 0.7043802245044184
#   time_since_restore: 124.12187004089355
#   time_this_iter_s: 124.12187004089355
#   time_total_s: 124.12187004089355
#   timestamp: 1670318985
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: f9c02394
#   warmup_time: 0.023080825805664062
#
# Result for _Trainable_4acd2afc:
#   average_test_score: 0.7008324479399146
#   date: 2022-12-06_10-30-11
#   done: true
#   experiment_id: 6f05d79c8be644a7aea8ef8d7adb62c1
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7008324479399146
#   pid: 868509
#   split0_test_score: 0.6910702873875679
#   split1_test_score: 0.6858445169351685
#   split2_test_score: 0.720413530965939
#   split3_test_score: 0.7223557577665227
#   split4_test_score: 0.6844781466443755
#   time_since_restore: 112.43631672859192
#   time_this_iter_s: 112.43631672859192
#   time_total_s: 112.43631672859192
#   timestamp: 1670319011
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 4acd2afc
#   warmup_time: 0.019457340240478516
#
# Result for _Trainable_51d259d0:
#   average_test_score: 0.7008324479399146
#   date: 2022-12-06_10-30-44
#   done: true
#   experiment_id: da0c4cd6f0f549c2bef33ff37f34a425
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7008324479399146
#   pid: 868505
#   split0_test_score: 0.6910702873875679
#   split1_test_score: 0.6858445169351685
#   split2_test_score: 0.720413530965939
#   split3_test_score: 0.7223557577665227
#   split4_test_score: 0.6844781466443755
#   time_since_restore: 106.19211745262146
#   time_this_iter_s: 106.19211745262146
#   time_total_s: 106.19211745262146
#   timestamp: 1670319044
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 51d259d0
#   warmup_time: 0.02291250228881836
#
# Result for _Trainable_697ead4a:
#   average_test_score: 0.7008324479399146
#   date: 2022-12-06_10-30-57
#   done: true
#   experiment_id: 0a74f61f145b4db1a43d3f7b615e26a7
#   hostname: A771-PHI-247
#   iterations_since_restore: 1
#   node_ip: 131.130.129.247
#   objective: 0.7008324479399146
#   pid: 868475
#   split0_test_score: 0.6910702873875679
#   split1_test_score: 0.6858445169351685
#   split2_test_score: 0.720413530965939
#   split3_test_score: 0.7223557577665227
#   split4_test_score: 0.6844781466443755
#   time_since_restore: 104.7737545967102
#   time_this_iter_s: 104.7737545967102
#   time_total_s: 104.7737545967102
#   timestamp: 1670319057
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 697ead4a
#   warmup_time: 0.018968820571899414

# %%
import joblib
ames_grid.best_params_
#joblib.dump(ames_grid,'ames_bayesian.bin')
# Out:
# {'n_estimators': 100,
#  'max_depth': 8,
#  'learning_rate': 0.1,
#  'min_child_weight': 1,
#  'gamma': 0.5,
#  'subsample': 0.8,
#  'colsample_bytree': 1.0}
