# %%
import pandas as pd
from molvs import Standardizer
from rdkit import Chem
import numpy as np
import rdkit
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from rdkit.Chem.SaltRemover import SaltRemover
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect
from rdkit.DataStructs.cDataStructs import ConvertToNumpyArray

# %%
er = pd.read_csv("../data/ER.csv")
def predefied_split(data):
    yield (data[data['Set'] == 'T'].index,data[data['Set'] == 'P'].index)

# %%
#Processing of molecules
s = Standardizer()
salts = SaltRemover()

def ecfp( mol, r=3, nBits=2048, errors_as_zeros=True):
    mol = Chem.MolFromSmiles(mol) if not isinstance(mol, rdkit.Chem.rdchem.Mol) else mol
    try:
        arr = np.zeros((1,))
        ConvertToNumpyArray(GetMorganFingerprintAsBitVect(mol, r, nBits), arr)
        return arr.astype(np.float32)
    except:
        return np.NaN if not errors_as_zeros else np.zeros((nBits,), dtype=np.float32)

def process(smiles): #Some of molecules are broken (2 instead of 1) we will remove this data
   try:
       m =  Chem.MolFromSmiles(smiles)
       m = s.standardize(m)
       m = salts(m)
       return Chem.MolToSmiles(m)
   except:
       return None

er['Smiles'] = er['Smiles'].apply(process)
er.dropna(inplace=True)
er['ecfp'] = er['Smiles'].apply(ecfp)
# Out:
# [14:49:49] SMILES Parse Error: syntax error while parsing: CCC1(c2ccccc2)C(=O)NC(=O)NC1=O,
# [14:49:49] SMILES Parse Error: Failed parsing SMILES 'CCC1(c2ccccc2)C(=O)NC(=O)NC1=O,' for input: 'CCC1(c2ccccc2)C(=O)NC(=O)NC1=O,'
# [14:49:49] SMILES Parse Error: syntax error while parsing: CCC1(CC)C(=O)NC(=O)NC1=O,
# [14:49:49] SMILES Parse Error: Failed parsing SMILES 'CCC1(CC)C(=O)NC(=O)NC1=O,' for input: 'CCC1(CC)C(=O)NC(=O)NC1=O,'
# [14:49:51] SMILES Parse Error: syntax error while parsing: Oc1cc2OC(=O)c3c(oc4cc(O)ccc43)-c2cc1,
# [14:49:51] SMILES Parse Error: Failed parsing SMILES 'Oc1cc2OC(=O)c3c(oc4cc(O)ccc43)-c2cc1,' for input: 'Oc1cc2OC(=O)c3c(oc4cc(O)ccc43)-c2cc1,'
# [14:49:52] SMILES Parse Error: syntax error while parsing: O=C1N(Cl)C(=O)NC(=O)N1Cl,
# [14:49:52] SMILES Parse Error: Failed parsing SMILES 'O=C1N(Cl)C(=O)NC(=O)N1Cl,' for input: 'O=C1N(Cl)C(=O)NC(=O)N1Cl,'
# [14:49:54] SMILES Parse Error: syntax error while parsing: CC1=NN=C(C(=O)N1N)c1ccccc1,
# [14:49:54] SMILES Parse Error: Failed parsing SMILES 'CC1=NN=C(C(=O)N1N)c1ccccc1,' for input: 'CC1=NN=C(C(=O)N1N)c1ccccc1,'
# [14:49:54] SMILES Parse Error: syntax error while parsing: CCSC1=NN=C(C(=O)N1N)C(C)(C)C,
# [14:49:54] SMILES Parse Error: Failed parsing SMILES 'CCSC1=NN=C(C(=O)N1N)C(C)(C)C,' for input: 'CCSC1=NN=C(C(=O)N1N)C(C)(C)C,'
# [14:49:55] SMILES Parse Error: syntax error while parsing: COc1c(CS(=O)c2[nH]c3ccc(cc3[n]2)OC(F)F)[n]ccc1OC,
# [14:49:55] SMILES Parse Error: Failed parsing SMILES 'COc1c(CS(=O)c2[nH]c3ccc(cc3[n]2)OC(F)F)[n]ccc1OC,' for input: 'COc1c(CS(=O)c2[nH]c3ccc(cc3[n]2)OC(F)F)[n]ccc1OC,'
# [14:49:55] SMILES Parse Error: syntax error while parsing: CC12CCC3C(C1CCC2O)C(Cc1cc(O)ccc13)CCCCCCCCCS(=O)CCCC(F)(F)C(F)(F)F,
# [14:49:55] SMILES Parse Error: Failed parsing SMILES 'CC12CCC3C(C1CCC2O)C(Cc1cc(O)ccc13)CCCCCCCCCS(=O)CCCC(F)(F)C(F)(F)F,' for input: 'CC12CCC3C(C1CCC2O)C(Cc1cc(O)ccc13)CCCCCCCCCS(=O)CCCC(F)(F)C(F)(F)F,'

# %%
er['Class'].astype("category").value_counts()
# Out:
# 0    5296
# 1    1979
# Name: Class, dtype: int64

# %%
estimator = XGBClassifier(
    objective= 'binary:logistic',
    tree_method='gpu_hist',
    nthread=-1,
    seed=42
)
parameters = {
    'n_estimators': [100],
    'max_depth': range (2, 10, 1),
    'learning_rate': [0.1, 0.01, 0.05],
}

# %%
grid_search = GridSearchCV(
    estimator=estimator,
    param_grid=parameters,
    scoring = 'roc_auc',
    n_jobs = 1,
    cv = 5,#predefied_split(),
    verbose=2
)

# %%
best = grid_search.fit(np.vstack(er['ecfp'].values),er['Class'])
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END ...learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.7s
# [CV] END ...learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ...learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.7s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   2.5s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   2.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   2.5s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   2.4s
# [CV] END ...learning_rate=0.1, max_depth=4, n_estimators=100; total time=   2.4s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   4.0s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   4.1s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   4.0s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   3.9s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   3.8s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=100; total time=   5.9s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=100; total time=   5.8s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=100; total time=   5.8s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=100; total time=   5.7s
# [CV] END ...learning_rate=0.1, max_depth=6, n_estimators=100; total time=   5.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   7.9s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   7.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   7.7s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   7.6s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   7.3s
# [CV] END ...learning_rate=0.1, max_depth=8, n_estimators=100; total time=  10.4s
# [CV] END ...learning_rate=0.1, max_depth=8, n_estimators=100; total time=  10.1s
# [CV] END ...learning_rate=0.1, max_depth=8, n_estimators=100; total time=  10.1s
# [CV] END ...learning_rate=0.1, max_depth=8, n_estimators=100; total time=   9.4s
# [CV] END ...learning_rate=0.1, max_depth=8, n_estimators=100; total time=   9.4s
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time=  12.7s
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time=  12.4s
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time=  12.4s
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time=  11.5s
# [CV] END ...learning_rate=0.1, max_depth=9, n_estimators=100; total time=  11.2s
# [CV] END ..learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=4, n_estimators=100; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   4.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   4.8s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   4.8s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   4.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   4.6s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=100; total time=   8.1s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=100; total time=   7.6s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=100; total time=   8.5s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=100; total time=   7.7s
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=100; total time=   7.6s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=  12.3s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=  11.3s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=  12.7s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=  10.8s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=  11.0s
# [CV] END ..learning_rate=0.01, max_depth=8, n_estimators=100; total time=  16.9s
# [CV] END ..learning_rate=0.01, max_depth=8, n_estimators=100; total time=  15.7s
# [CV] END ..learning_rate=0.01, max_depth=8, n_estimators=100; total time=  17.4s
# [CV] END ..learning_rate=0.01, max_depth=8, n_estimators=100; total time=  14.5s
# [CV] END ..learning_rate=0.01, max_depth=8, n_estimators=100; total time=  14.7s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=  22.7s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=  20.9s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=  22.5s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=  18.8s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=  20.0s
# [CV] END ..learning_rate=0.05, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=2, n_estimators=100; total time=   0.8s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   1.5s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.05, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   2.5s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   2.5s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   2.5s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   2.4s
# [CV] END ..learning_rate=0.05, max_depth=4, n_estimators=100; total time=   2.5s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   4.3s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   4.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   4.2s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   4.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   4.2s
# [CV] END ..learning_rate=0.05, max_depth=6, n_estimators=100; total time=   6.5s
# [CV] END ..learning_rate=0.05, max_depth=6, n_estimators=100; total time=   6.3s
# [CV] END ..learning_rate=0.05, max_depth=6, n_estimators=100; total time=   6.5s
# [CV] END ..learning_rate=0.05, max_depth=6, n_estimators=100; total time=   6.1s
# [CV] END ..learning_rate=0.05, max_depth=6, n_estimators=100; total time=   6.2s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   9.6s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   9.1s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   9.0s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   8.8s
# [CV] END ..learning_rate=0.05, max_depth=7, n_estimators=100; total time=   8.8s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=100; total time=  12.4s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=100; total time=  11.5s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=100; total time=  12.2s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=100; total time=  11.3s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=100; total time=  11.1s
# [CV] END ..learning_rate=0.05, max_depth=9, n_estimators=100; total time=  15.6s
# [CV] END ..learning_rate=0.05, max_depth=9, n_estimators=100; total time=  14.8s
# [CV] END ..learning_rate=0.05, max_depth=9, n_estimators=100; total time=  14.8s
# [CV] END ..learning_rate=0.05, max_depth=9, n_estimators=100; total time=  13.7s
# [CV] END ..learning_rate=0.05, max_depth=9, n_estimators=100; total time=  13.8s

# %%
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_ca...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None, nthread=-1,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, reg_alpha=None, ...),
#              n_jobs=1,
#              param_grid={'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': range(2, 10), 'n_estimators': [100]},
#              scoring='roc_auc', verbose=2)
